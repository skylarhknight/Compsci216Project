# %% [markdown]
# <h1>Importing Data</h1>

# %%
#import necessary libraries (might not use all but just in case)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import scipy
import glob
import matplotlib.colors as mcolors
from scipy import stats

# %%
#importing the main dataset
crash_data = pd.read_csv('crash_data.csv')

# %%
# fixing the index
crash_data.set_index('Index', inplace=True)
#crash_data.drop(columns=['Unnamed: 7'], inplace=True)

# %%
crash_data
# Out:
#                                         Disabling Injury(A) Evident Injury(B)  \
# Index
# Person (Between 65 and 75) Involved                     490             2,983
# Person (Between 65 and 75) Not Involved               3,916            20,953
# Person (>75) Involved                                   192             1,442
# Person (>75) Not Involved                             4,214            22,494
# Teen Involved                                           468             3,495
# Teen Not Involved                                     3,938            20,441
# Alcohol Involved                                      1,448             4,852
# Alcohol Not Involved                                  8,954            55,698
# Sunday                                                1,434             7,876
# Monday                                                1,223             8,224
# Tuesday                                               1,436             8,053
# Wednesday                                             1,363             8,302
# Thursday                                              1,327             8,239
# Friday                                                1,720            10,340
# Saturday                                              1,899             9,516
# FEMALE                                                3,881            26,438
# MALE                                                  6,236            32,398
# TRUCK/TRACTOR                                             5                21
# MOTORCYCLE                                              655             1,523
# PASSENGER CAR                                         2,908            20,640
# PICKUP                                                1,127             5,760
# POLICE                                                   24               105
#
#                                         Fatal(K) No Injury(O)  \
# Index
# Person (Between 65 and 75) Involved          240       33,131
# Person (Between 65 and 75) Not Involved    1,458      226,782
# Person (>75) Involved                        141       14,198
# Person (>75) Not Involved                  1,557      245,715
# Teen Involved                                146       35,894
# Teen Not Involved                          1,552      224,019
# Alcohol Involved                             820       13,526
# Alcohol Not Involved                       3,438      584,444
# Sunday                                       614       60,134
# Monday                                       616       84,821
# Tuesday                                      474       87,331
# Wednesday                                    507       88,987
# Thursday                                     632       89,042
# Friday                                       700      105,702
# Saturday                                     715       81,953
# FEMALE                                     1,454      259,756
# MALE                                       2,703      294,156
# TRUCK/TRACTOR                                  5          355
# MOTORCYCLE                                   212          822
# PASSENGER CAR                              1,068      230,663
# PICKUP                                       464       66,726
# POLICE                                        14        1,726
#
#                                         Possible Injury(C) Unknown
# Index
# Person (Between 65 and 75) Involved                  6,690     290
# Person (Between 65 and 75) Not Involved             42,694  23,575
# Person (>75) Involved                                2,746     137
# Person (>75) Not Involved                           46,638  23,728
# Teen Involved                                        7,676     274
# Teen Not Involved                                   41,708  23,591
# Alcohol Involved                                     5,411     433
# Alcohol Not Involved                               130,816  40,681
# Sunday                                              14,209   6,476
# Monday                                              18,672   5,660
# Tuesday                                             19,999   5,194
# Wednesday                                           19,861   5,465
# Thursday                                            19,736   5,420
# Friday                                              24,286   6,341
# Saturday                                            19,464   6,558
# FEMALE                                              65,056   2,288
# MALE                                                66,941   3,009
# TRUCK/TRACTOR                                           53      17
# MOTORCYCLE                                             744     122
# PASSENGER CAR                                       50,795  16,940
# PICKUP                                              11,634   3,622
# POLICE                                                 186      46

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
#fatalities per factor
#basically just made the colors lighter/darker based on amount of fatalities

# converting any commas in the DataFrame to dots and convert to numeric
crash_data = crash_data.replace(',', '', regex=True).astype(int)

# color and brightness
def modify_brightness(color, brightness_factor):
    hsv = plt.cm.colors.rgb_to_hsv(color[:3])
    hsv[2] = hsv[2] * brightness_factor
    rgb = plt.cm.colors.hsv_to_rgb(hsv)
    return rgb

r
original_cmap = plt.get_cmap('Blues')
brightness_factor = 0.9  

# brightness of each color in the original colormap
modified_colors = [modify_brightness(original_cmap(i), brightness_factor) for i in range(original_cmap.N)]

# new colormap
modified_cmap = plt.cm.colors.ListedColormap(modified_colors)

# Normalize the 'Fatal(K)' values to range from 0 to 1
normalize = plt.Normalize(vmin=crash_data['Fatal(K)'].min(), vmax=crash_data['Fatal(K)'].max())

# plotting
plt.figure(figsize=(12, 8))
bars = plt.bar(crash_data.index, crash_data['Fatal(K)'], color=modified_cmap(normalize(crash_data['Fatal(K)'])))
plt.title('Fatal Injuries for Each Variable')
plt.xlabel('')
plt.ylabel('Fatal Injuries')
plt.xticks(rotation=90)
plt.grid(True)


sm = plt.cm.ScalarMappable(cmap=modified_cmap, norm=normalize)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Normalized Fatal(K)')

plt.show()
# Out:
# /var/folders/26/t1nd2f_d7h5ftkrz4132h9p00000gq/T/ipykernel_85016/1135945356.py:41: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
#using rows as independent data
crash_data_transposed = crash_data.transpose()

#correlation matrix
correlation_matrix = crash_data_transposed.corr()

import seaborn as sns
import matplotlib.pyplot as plt

# heatmap
# kind of hard to read but still has good info
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#correlation amongst the independent variables 


crash_data_Filtered = crash_data.drop(columns=['Unknown'])

corr_matrix = crash_data_Filtered.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
#scatterplot 

plt.figure(figsize=(8, 6))
sns.scatterplot(data=crash_data, x='No Injury(O)', y='Fatal(K)')
plt.title('No Injuries vs. Fatal Injuries')
plt.grid(True)
plt.show()

# %%
#analyzing age correlation
subset_data = crash_data.iloc[0:6]

# Create a scatter plot using the index as one of the variables
plt.figure(figsize=(8, 6))
plt.scatter(subset_data.index, subset_data['Fatal(K)'])
plt.title('Index vs. Fatal Injuries')
plt.xlabel('Index')
plt.ylabel('Fatal Injuries')
plt.grid(True)

# Rotate the x-axis tick labels by 45 degrees
plt.xticks(rotation=90)

plt.show()

# %%
crash_data_reset
# Out:
#                                       Index  Disabling Injury(A)  \
# 0       Person (Between 65 and 75) Involved                  490
# 1   Person (Between 65 and 75) Not Involved                 3916
# 2                     Person (>75) Involved                  192
# 3                 Person (>75) Not Involved                 4214
# 4                             Teen Involved                  468
# 5                         Teen Not Involved                 3938
# 6                          Alcohol Involved                 1448
# 7                      Alcohol Not Involved                 8954
# 8                                    Sunday                 1434
# 9                                    Monday                 1223
# 10                                  Tuesday                 1436
# 11                                Wednesday                 1363
# 12                                 Thursday                 1327
# 13                                   Friday                 1720
# 14                                 Saturday                 1899
# 15                                   FEMALE                 3881
# 16                                     MALE                 6236
# 17                            TRUCK/TRACTOR                    5
# 18                               MOTORCYCLE                  655
# 19                            PASSENGER CAR                 2908
# 20                                   PICKUP                 1127
# 21                                   POLICE                   24
#
#     Evident Injury(B)  Fatal(K)  No Injury(O)  Possible Injury(C)  Unknown
# 0                2983       240         33131                6690      290
# 1               20953      1458        226782               42694    23575
# 2                1442       141         14198                2746      137
# 3               22494      1557        245715               46638    23728
# 4                3495       146         35894                7676      274
# 5               20441      1552        224019               41708    23591
# 6                4852       820         13526                5411      433
# 7               55698      3438        584444              130816    40681
# 8                7876       614         60134               14209     6476
# 9                8224       616         84821               18672     5660
# 10               8053       474         87331               19999     5194
# 11               8302       507         88987               19861     5465
# 12               8239       632         89042               19736     5420
# 13              10340       700        105702               24286     6341
# 14               9516       715         81953               19464     6558
# 15              26438      1454        259756               65056     2288
# 16              32398      2703        294156               66941     3009
# 17                 21         5           355                  53       17
# 18               1523       212           822                 744      122
# 19              20640      1068        230663               50795    16940
# 20               5760       464         66726               11634     3622
# 21                105        14          1726                 186       46
